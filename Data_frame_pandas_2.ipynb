# %%
import pandas as pd
import seaborn as sns
from matplotlib import pyplot as plt

# %%
data_mobile={'Mobile':['iPhone','Redmi','Vivo','Samsumg','Nokia','Infinix'],
            'Rating':[1,3,2,5,15,6],
            'Price':[75000,15000,15000,10000,1500,12000],
            'Color':['White','Black','Mat_Black','Blue','Black','Blue']}
data_mobile
# Out:
# {'Mobile': ['iPhone', 'Redmi', 'Vivo', 'Samsumg', 'Nokia', 'Infinix'],
#  'Rating': [1, 3, 2, 5, 15, 6],
#  'Price': [75000, 15000, 15000, 10000, 1500, 12000],
#  'Color': ['White', 'Black', 'Mat_Black', 'Blue', 'Black', 'Blue']}

# %%
revised_data = pd.DataFrame(data_mobile)
revised_data
# Out:
#     Mobile  Rating  Price      Color
# 0   iPhone       1  75000      White
# 1    Redmi       3  15000      Black
# 2     Vivo       2  15000  Mat_Black
# 3  Samsumg       5  10000       Blue
# 4    Nokia      15   1500      Black
# 5  Infinix       6  12000       Blue

# %%
revised_data.insert(4,"State",["UP","Banglore","Hydarabad","MP","UP","Banglore"])
revised_data
# Out:
#     Mobile  Rating  Price      Color      State
# 0   iPhone       1  75000      White         UP
# 1    Redmi       3  15000      Black   Banglore
# 2     Vivo       2  15000  Mat_Black  Hydarabad
# 3  Samsumg       5  10000       Blue         MP
# 4    Nokia      15   1500      Black         UP
# 5  Infinix       6  12000       Blue   Banglore

# %%
revised_data.insert(5,'Most_Sale',[2016,2018,2016,2020,2010,2021])
revised_data
# Out:
#     Mobile  Rating  Price      Color      State  Most_Sale
# 0   iPhone       1  75000      White         UP       2016
# 1    Redmi       3  15000      Black   Banglore       2018
# 2     Vivo       2  15000  Mat_Black  Hydarabad       2016
# 3  Samsumg       5  10000       Blue         MP       2020
# 4    Nokia      15   1500      Black         UP       2010
# 5  Infinix       6  12000       Blue   Banglore       2021

# %%
revised_data.describe()
# Out:
#           Rating         Price    Most_Sale
# count   6.000000      6.000000     6.000000
# mean    5.333333  21416.666667  2016.833333
# std     5.085928  26717.815529     3.920034
# min     1.000000   1500.000000  2010.000000
# 25%     2.250000  10500.000000  2016.000000
# 50%     4.000000  13500.000000  2017.000000
# 75%     5.750000  15000.000000  2019.500000
# max    15.000000  75000.000000  2021.000000

# %%
revised_data.mean()
# Out:
# C:\Users\NISHANT\AppData\Local\Temp\ipykernel_22568\3877449494.py:1: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   revised_data.mean()
# Rating           5.333333
# Price        21416.666667
# Most_Sale     2016.833333
# dtype: float64

# %%
x=revised_data.iloc[:,5].values

# %%
y=revised_data.iloc[:,2].values

# %%
plt.bar(x,y)
plt.grid()
plt.plot()
plt.show()

# %%
revised_data.head(3)
# Out:
#    Mobile  Rating  Price      Color      State  Most_Sale
# 0  iPhone       1  75000      White         UP       2016
# 1   Redmi       3  15000      Black   Banglore       2018
# 2    Vivo       2  15000  Mat_Black  Hydarabad       2016

# %%
revised_data.tail(4)
# Out:
#     Mobile  Rating  Price      Color      State  Most_Sale
# 2     Vivo       2  15000  Mat_Black  Hydarabad       2016
# 3  Samsumg       5  10000       Blue         MP       2020
# 4    Nokia      15   1500      Black         UP       2010
# 5  Infinix       6  12000       Blue   Banglore       2021

# %%
revised_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6 entries, 0 to 5
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Mobile     6 non-null      object
#  1   Rating     6 non-null      int64
#  2   Price      6 non-null      int64
#  3   Color      6 non-null      object
#  4   State      6 non-null      object
#  5   Most_Sale  6 non-null      int64
# dtypes: int64(3), object(3)
# memory usage: 416.0+ bytes

# %% [markdown]
# # Functions...

# %%
revised_data.mean()
# Out:
# C:\Users\NISHANT\AppData\Local\Temp\ipykernel_22568\3877449494.py:1: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   revised_data.mean()
# Rating           5.333333
# Price        21416.666667
# Most_Sale     2016.833333
# dtype: float64

# %%
revised_data.median()
# Out:
# C:\Users\NISHANT\AppData\Local\Temp\ipykernel_22568\306044631.py:1: FutureWarning: The default value of numeric_only in DataFrame.median is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   revised_data.median()
# Rating           4.0
# Price        13500.0
# Most_Sale     2017.0
# dtype: float64

# %%
revised_data.mode()
# Out:
#     Mobile  Rating    Price  Color     State  Most_Sale
# 0  Infinix       1  15000.0  Black  Banglore     2016.0
# 1    Nokia       2      NaN   Blue        UP        NaN
# 2    Redmi       3      NaN    NaN       NaN        NaN
# 3  Samsumg       5      NaN    NaN       NaN        NaN
# 4     Vivo       6      NaN    NaN       NaN        NaN
# 5   iPhone      15      NaN    NaN       NaN        NaN

# %%
revised_data.std()
# Out:
# C:\Users\NISHANT\AppData\Local\Temp\ipykernel_22568\1927481219.py:1: FutureWarning: The default value of numeric_only in DataFrame.std is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   revised_data.std()
# Rating           5.085928
# Price        26717.815529
# Most_Sale        3.920034
# dtype: float64

# %%
revised_data.var()
# Out:
# C:\Users\NISHANT\AppData\Local\Temp\ipykernel_22568\3130438836.py:1: FutureWarning: The default value of numeric_only in DataFrame.var is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   revised_data.var()
# Rating       2.586667e+01
# Price        7.138417e+08
# Most_Sale    1.536667e+01
# dtype: float64

# %%
revised_data.count()
# Out:
# Mobile       6
# Rating       6
# Price        6
# Color        6
# State        6
# Most_Sale    6
# dtype: int64

# %% [markdown]
# # Pandas-cleaning empty cells

# %%
dataset2 = sns.load_dataset("iris")

# %%
dataset2
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
dataset2.isnull()
# Out:
#      sepal_length  sepal_width  petal_length  petal_width  species
# 0           False        False         False        False    False
# 1           False        False         False        False    False
# 2           False        False         False        False    False
# 3           False        False         False        False    False
# 4           False        False         False        False    False
# ..            ...          ...           ...          ...      ...
# 145         False        False         False        False    False
# 146         False        False         False        False    False
# 147         False        False         False        False    False
# 148         False        False         False        False    False
# 149         False        False         False        False    False
#
# [150 rows x 5 columns]

# %%
data = pd.read_csv("C:\\Users\\NISHANT\\3D Objects\\CSV_Files\\Covid.csv")

# %%
data
# Out:
#        # Country,\nOther Total\nCases Total\nDeaths  New\nDeaths  \
# 0      1             USA   98,166,904     1,084,282          NaN
# 1      2           India   44,587,307       528,629          NaN
# 2      3          France   35,342,950       155,078          NaN
# 3      4          Brazil   34,706,757       686,027          NaN
# 4      5         Germany   33,312,373       149,948          NaN
# ..   ...             ...          ...           ...          ...
# 225  226            Niue           80           NaN          NaN
# 226  227    Vatican City           29           NaN          NaN
# 227  228          Tuvalu           20           NaN          NaN
# 228  229  Western Sahara           10             1          NaN
# 229  230      MS Zaandam            9             2          NaN
#
#     Total\nRecovered Active\nCases Serious,\nCritical Tot Cases/\n1M pop  \
# 0         94,962,112     2,120,510              2,970            293,206
# ...

# %%
data.isnull()
# Out:
#          #  Country,\nOther  Total\nCases  Total\nDeaths  New\nDeaths  \
# 0    False            False         False          False         True
# 1    False            False         False          False         True
# 2    False            False         False          False         True
# 3    False            False         False          False         True
# 4    False            False         False          False         True
# ..     ...              ...           ...            ...          ...
# 225  False            False         False           True         True
# 226  False            False         False           True         True
# 227  False            False         False           True         True
# 228  False            False         False          False         True
# 229  False            False         False          False         True
#
#      Total\nRecovered  Active\nCases  Serious,\nCritical  Tot Cases/\n1M pop  \
# ...

# %%
data2= data.head(50)

# %%
data2
# Out:
#      # Country,\nOther Total\nCases Total\nDeaths  New\nDeaths  \
# 0    1             USA   98,166,904     1,084,282          NaN
# 1    2           India   44,587,307       528,629          NaN
# 2    3          France   35,342,950       155,078          NaN
# 3    4          Brazil   34,706,757       686,027          NaN
# 4    5         Germany   33,312,373       149,948          NaN
# 5    6        S. Korea   24,769,101        28,406         42.0
# 6    7              UK   23,621,952       189,919          NaN
# 7    8           Italy   22,432,803       177,054          NaN
# 8    9           Japan   21,229,216        44,678          NaN
# 9   10          Russia   20,948,470       387,163          NaN
# 10  11          Turkey   16,873,793       101,139          NaN
# 11  12           Spain   13,412,263       114,084          NaN
# 12  13         Vietnam   11,477,886        43,148          NaN
# 13  14       Australia   10,209,239        14,984          NaN
# ...

# %%
data2.isnull()
# Out:
#         #  Country,\nOther  Total\nCases  Total\nDeaths  New\nDeaths  \
# 0   False            False         False          False         True
# 1   False            False         False          False         True
# 2   False            False         False          False         True
# 3   False            False         False          False         True
# 4   False            False         False          False         True
# 5   False            False         False          False        False
# 6   False            False         False          False         True
# 7   False            False         False          False         True
# 8   False            False         False          False         True
# 9   False            False         False          False         True
# 10  False            False         False          False         True
# 11  False            False         False          False         True
# 12  False            False         False          False         True
# ...

# %%
y= data2.iloc[:,7].values

# %%
y
# Out:
# array(['2,970', '698', '869', '8,318', '1,406', '352', '146', '141',
#        '204', '2,300', '975', '339', '106', '49', '294', '35', '157',
#        '4,798', '2,771', nan, '342', '3,086', '61', '177', '47', '115',
#        '43', nan, '1,496', '101', '124', '48', '99', '147', '39', '54',
#        '192', '696', '123', nan, '13', '21', '33', '18', '1,331', '9',
#        '22', nan, nan, '8'], dtype=object)

# %%
import numpy as np

# %%
x=data2.loc[5,'Total\nCases']

# %%
x
# Out:
# '24,769,101'

# %%
normalized_df=(revised_data-revised_data.mean())/revised_data.std()
# Out:
# C:\Users\NISHANT\AppData\Local\Temp\ipykernel_22568\929956205.py:1: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   normalized_df=(revised_data-revised_data.mean())/revised_data.std()
# C:\Users\NISHANT\AppData\Local\Temp\ipykernel_22568\929956205.py:1: FutureWarning: The default value of numeric_only in DataFrame.std is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   normalized_df=(revised_data-revised_data.mean())/revised_data.std()

# %%
normalized_df
# Out:
#   Color Mobile  Most_Sale     Price    Rating State
# 0   NaN    NaN  -0.212583  2.005528 -0.852024   NaN
# 1   NaN    NaN   0.297616 -0.240164 -0.458782   NaN
# 2   NaN    NaN  -0.212583 -0.240164 -0.655403   NaN
# 3   NaN    NaN   0.807816 -0.427305 -0.065540   NaN
# 4   NaN    NaN  -1.743182 -0.745445  1.900669   NaN
# 5   NaN    NaN   1.062916 -0.352449  0.131081   NaN
