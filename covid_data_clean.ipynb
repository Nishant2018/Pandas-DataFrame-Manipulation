# %%
import pandas as pd
import seaborn as sns
import numpy as np
from matplotlib import pyplot as plt

# %%
df = pd.read_csv("C:\\Users\\NISHANT\\3D Objects\\CSV_Files\\Covid.csv")
df
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_7872\668804828.py in <module>
# ----> 1 df = pd.read_csv("C:\\Users\\NISHANT\\3D Objects\\CSV_Files\\Covid.csv")
#       2 df
#
# ~\anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ...

# %%
df.info(show_counts=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 230 entries, 0 to 229
# Data columns (total 13 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   #                  230 non-null    int64
#  1   Country,
# Other     230 non-null    object
#  2   Total
# Cases        230 non-null    object
#  3   Total
# Deaths       225 non-null    object
#  4   New
# Deaths         3 non-null      float64
#  5   Total
# Recovered    214 non-null    object
#  6   Active
# Cases       215 non-null    object
#  7   Serious,
# Critical  147 non-null    object
#  8   Tot Cases/
# 1M pop  228 non-null    object
#  9   Deaths/
# 1M pop     223 non-null    object
#  10  Total
# Tests        214 non-null    object
#  11  Tests/
# 1M pop      214 non-null    object
#  12  Population         228 non-null    object
# dtypes: float64(1), int64(1), object(11)
# memory usage: 23.5+ KB

# %%
df.describe().T
# Out:
#              count   mean        std  min    25%    50%     75%    max
# #            230.0  115.5  66.539462  1.0  58.25  115.5  172.75  230.0
# New\nDeaths    3.0   18.0  21.000000  3.0   6.00    9.0   25.50   42.0

# %%
df.shape
# Out:
# (230, 13)

# %%
df.shape[1]
# Out:
# 13

# %%
df.shape[0]
# Out:
# 230

# %%
list(df.columns)
# Out:
# ['#',
#  'Country,\nOther',
#  'Total\nCases',
#  'Total\nDeaths',
#  'New\nDeaths',
#  'Total\nRecovered',
#  'Active\nCases',
#  'Serious,\nCritical',
#  'Tot Cases/\n1M pop',
#  'Deaths/\n1M pop',
#  'Total\nTests',
#  'Tests/\n1M pop',
#  'Population']

# %%
df_head = df.head(50)
df_head
# Out:
#      # Country,\nOther Total\nCases Total\nDeaths  New\nDeaths  \
# 0    1             USA   98,166,904     1,084,282          NaN
# 1    2           India   44,587,307       528,629          NaN
# 2    3          France   35,342,950       155,078          NaN
# 3    4          Brazil   34,706,757       686,027          NaN
# 4    5         Germany   33,312,373       149,948          NaN
# 5    6        S. Korea   24,769,101        28,406         42.0
# 6    7              UK   23,621,952       189,919          NaN
# 7    8           Italy   22,432,803       177,054          NaN
# 8    9           Japan   21,229,216        44,678          NaN
# 9   10          Russia   20,948,470       387,163          NaN
# 10  11          Turkey   16,873,793       101,139          NaN
# 11  12           Spain   13,412,263       114,084          NaN
# 12  13         Vietnam   11,477,886        43,148          NaN
# 13  14       Australia   10,209,239        14,984          NaN
# ...

# %%
df_head.describe().T
# Out:
#              count  mean        std  min    25%   50%    75%   max
# #             50.0  25.5  14.577380  1.0  13.25  25.5  37.75  50.0
# New\nDeaths    2.0  25.5  23.334524  9.0  17.25  25.5  33.75  42.0

# %%
arr = np.array(df_head["Total\nTests"])

# %%
arr
# Out:
# array(['1,118,158,870', '894,416,853', '271,490,188', '63,776,166',
#        '122,332,384', '15,804,065', '522,526,476', '246,636,495',
#        '76,201,407', '273,400,000', '162,743,369', '471,036,328',
#        '85,826,548', '78,835,048', '35,716,069', '21,107,399',
#        '54,095,556', '18,393,211', '108,656,989', '25,998,416',
#        '36,572,720', '37,335,609', '44,988,307', '19,521,252',
#        '197,543,761', '94,139,966', '64,604,259', nan, '17,270,775',
#        '41,373,364', '45,128,974', '35,555,508', '64,928,884',
#        '35,126,382', '56,212,735', '22,318,542', '26,174,429',
#        '32,796,350', '25,094,131', '128,397,719', '18,965,590',
#        '19,239,264', '11,030,499', '11,394,556', '14,872,260',
#        '24,345,019', '7,298,163', '16,920,079', '7,544,063', '54,352,132'],
#       dtype=object)

# %%
df_head.isnull().sum()
# Out:
# #                      0
# Country,\nOther        0
# Total\nCases           0
# Total\nDeaths          0
# New\nDeaths           48
# Total\nRecovered       0
# Active\nCases          0
# Serious,\nCritical     5
# Tot Cases/\n1M pop     0
# Deaths/\n1M pop        0
# Total\nTests           1
# Tests/\n1M pop         1
# Population             0
# dtype: int64

# %%
df_head.isnull().sum().sum()
# Out:
# 55

# %%
df_head["Total\nTests"].fillna(method="pad")
# Out:
# 0     1,118,158,870
# 1       894,416,853
# 2       271,490,188
# 3        63,776,166
# 4       122,332,384
# 5        15,804,065
# 6       522,526,476
# 7       246,636,495
# 8        76,201,407
# 9       273,400,000
# 10      162,743,369
# 11      471,036,328
# 12       85,826,548
# 13       78,835,048
# 14       35,716,069
# 15       21,107,399
# 16       54,095,556
# 17       18,393,211
# 18      108,656,989
# 19       25,998,416
# 20       36,572,720
# 21       37,335,609
# 22       44,988,307
# 23       19,521,252
# 24      197,543,761
# 25       94,139,966
# 26       64,604,259
# 27       64,604,259
# 28       17,270,775
# 29       41,373,364
# 30       45,128,974
# 31       35,555,508
# 32       64,928,884
# 33       35,126,382
# 34       56,212,735
# 35       22,318,542
# 36       26,174,429
# 37       32,796,350
# 38       25,094,131
# 39      128,397,719
# 40       18,965,590
# 41       19,239,264
# 42       11,030,499
# 43       11,394,556
# 44       14,872,260
# ...

# %%
df_head["Tests/\n1M pop"].fillna(method="backfill")
# Out:
# 0      3,339,729
# 1        635,857
# 2      4,139,547
# 3        296,146
# 4      1,458,359
# 5        307,892
# 6      7,628,357
# 7      4,092,684
# 8        606,772
# 9      1,875,095
# 10     1,902,052
# 11    10,082,298
# 12       867,342
# 13     3,024,116
# 14       776,264
# 15     1,226,358
# 16       628,851
# 17       139,806
# 18       389,264
# 19     1,088,319
# 20       709,974
# 21       989,290
# 22     4,436,467
# 23       451,963
# 24    21,787,811
# 25     9,125,063
# 26     1,947,021
# 27       246,450
# 28       246,450
# 29     4,436,346
# 30     2,344,339
# 31     3,047,194
# 32     1,691,366
# 33     1,042,815
# 34     5,235,528
# 35     2,543,819
# 36       430,811
# 37       291,500
# 38     1,318,569
# 39    22,004,939
# 40     1,855,920
# 41       456,286
# 42     1,274,758
# 43     1,186,160
# 44        88,586
# 45     4,096,043
# 46     1,336,613
# 47     4,263,340
# 48     1,540,170
# 49     7,147,553
# Name: Tests/\n1M pop, dtype: object

# %%
df_head
# Out:
#      # Country,\nOther Total\nCases Total\nDeaths  New\nDeaths  \
# 0    1             USA   98,166,904     1,084,282          NaN
# 1    2           India   44,587,307       528,629          NaN
# 2    3          France   35,342,950       155,078          NaN
# 3    4          Brazil   34,706,757       686,027          NaN
# 4    5         Germany   33,312,373       149,948          NaN
# 5    6        S. Korea   24,769,101        28,406         42.0
# 6    7              UK   23,621,952       189,919          NaN
# 7    8           Italy   22,432,803       177,054          NaN
# 8    9           Japan   21,229,216        44,678          NaN
# 9   10          Russia   20,948,470       387,163          NaN
# 10  11          Turkey   16,873,793       101,139          NaN
# 11  12           Spain   13,412,263       114,084          NaN
# 12  13         Vietnam   11,477,886        43,148          NaN
# 13  14       Australia   10,209,239        14,984          NaN
# ...

# %%
df_head.dropna()
# Out:
#      # Country,\nOther Total\nCases Total\nDeaths  New\nDeaths  \
# 5    6        S. Korea   24,769,101        28,406         42.0
# 28  29        Thailand    4,681,309        32,767          9.0
#
#    Total\nRecovered Active\nCases Serious,\nCritical Tot Cases/\n1M pop  \
# 5        24,013,461       727,234                352            482,547
# 28        4,642,083         6,459              1,496             66,801
#
#    Deaths/\n1M pop Total\nTests Tests/\n1M pop  Population
# 5              553   15,804,065        307,892  51,329,899
# 28             468   17,270,775        246,450  70,078,203

# %%
df_head.groupby("Country,\nOther")

# %%
print(df_head.groupby("Country,\nOther").groups)
# Out:
# {'Argentina': [14], 'Australia': [13], 'Austria': [24], 'Bangladesh': [44], 'Belgium': [31], 'Brazil': [3], 'Canada': [32], 'Chile': [30], 'Colombia': [20], 'Czechia': [34], 'DPRK': [27], 'Denmark': [39], 'France': [2], 'Georgia': [47], 'Germany': [4], 'Greece': [25], 'Hong Kong': [49], 'Hungary': [43], 'India': [1], 'Indonesia': [18], 'Iran': [16], 'Iraq': [41], 'Israel': [29], 'Italy': [7], 'Japan': [8], 'Malaysia': [26], 'Mexico': [17], 'Netherlands': [15], 'New Zealand': [48], 'Peru': [33], 'Philippines': [37], 'Poland': [21], 'Portugal': [22], 'Romania': [38], 'Russia': [9], 'S. Korea': [5], 'Serbia': [42], 'Singapore': [45], 'Slovakia': [46], 'South Africa': [36], 'Spain': [11], 'Sweden': [40], 'Switzerland': [35], 'Taiwan': [19], 'Thailand': [28], 'Turkey': [10], 'UK': [6], 'USA': [0], 'Ukraine': [23], 'Vietnam': [12]}

# %%
print(df.groupby("Country,\nOther").groups)
# Out:
# {'Afghanistan': [116], 'Albania': [100], 'Algeria': [104], 'Andorra': [152], 'Angola': [128], 'Anguilla': [216], 'Antigua and Barbuda': [201], 'Argentina': [14], 'Armenia': [94], 'Aruba': [155], 'Australia': [13], 'Austria': [24], 'Azerbaijan': [75], 'Bahamas': [162], 'Bahrain': [78], 'Bangladesh': [44], 'Barbados': [129], 'Belarus': [70], 'Belgium': [31], 'Belize': [141], 'Benin': [169], 'Bermuda': [180], 'Bhutan': [147], 'Bolivia': [65], 'Bosnia and Herzegovina': [95], 'Botswana': [101], 'Brazil': [3], 'British Virgin Islands': [207], 'Brunei': [110], 'Bulgaria': [57], 'Burkina Faso': [173], 'Burundi': [149], 'CAR': [189], 'Cabo Verde': [146], 'Cambodia': [124], 'Cameroon': [126], 'Canada': [32], 'Caribbean Netherlands': [196], 'Cayman Islands': [167], 'Chad': [206], 'Channel Islands': [132], 'Chile': [30], 'China': [107], 'Colombia': [20], 'Comoros': [203], 'Congo': [171], 'Cook Islands': [210], 'Costa Rica': [66], 'Croatia': [59], 'Cuba': [64], 'Curaçao': [153], 'Cyprus': [86], '
# ...

# %%
print(df_head.groupby(["New\nDeaths"]).groups)
# Out:
# {9.0: [28], 42.0: [5]}

# %%
df_end = df.copy().tail(50)
df_end
# Out:
#        #         Country,\nOther Total\nCases Total\nDeaths  New\nDeaths  \
# 180  181                 Bermuda       18,154           148          NaN
# 181  182             South Sudan       17,823           138          NaN
# 182  183              Tajikistan       17,786           125          NaN
# 183  184       Equatorial Guinea       17,012           183          NaN
# 184  185                   Tonga       16,182            12          NaN
# 185  186                   Samoa       15,925            29          NaN
# 186  187                Dominica       15,747            74          NaN
# 187  188                Djibouti       15,690           189          NaN
# 188  189        Marshall Islands       15,275            17          NaN
# 189  190                     CAR       14,913           113          NaN
# 190  191                  Monaco       14,608            63          NaN
# 191  192                  Gambia       12,508           372          NaN
# ...

# %%
print(pd.merge(df_head,df_end,on="New\nDeaths"))
# Out:
#       #_x Country,\nOther_x Total\nCases_x Total\nDeaths_x  New\nDeaths  \
# 0       1               USA     98,166,904       1,084,282          NaN
# 1       1               USA     98,166,904       1,084,282          NaN
# 2       1               USA     98,166,904       1,084,282          NaN
# 3       1               USA     98,166,904       1,084,282          NaN
# 4       1               USA     98,166,904       1,084,282          NaN
# ...   ...               ...            ...             ...          ...
# 2395   50         Hong Kong      1,761,381          10,153          NaN
# 2396   50         Hong Kong      1,761,381          10,153          NaN
# 2397   50         Hong Kong      1,761,381          10,153          NaN
# 2398   50         Hong Kong      1,761,381          10,153          NaN
# 2399   50         Hong Kong      1,761,381          10,153          NaN
#
#      Total\nRecovered_x Active\nCases_x Serious,\nCritical_x  \
# ...

# %%
df.plot.bar(stacked=True)
# Out:
# <AxesSubplot:>

# %%
df_head.plot()
# Out:
# <AxesSubplot:>

# %%
df_head.plot.bar(stacked=True)
# Out:
# <AxesSubplot:>

# %%
print(df_head["Country,\nOther"].str.upper())
# Out:
# 0              USA
# 1            INDIA
# 2           FRANCE
# 3           BRAZIL
# 4          GERMANY
# 5         S. KOREA
# 6               UK
# 7            ITALY
# 8            JAPAN
# 9           RUSSIA
# 10          TURKEY
# 11           SPAIN
# 12         VIETNAM
# 13       AUSTRALIA
# 14       ARGENTINA
# 15     NETHERLANDS
# 16            IRAN
# 17          MEXICO
# 18       INDONESIA
# 19          TAIWAN
# 20        COLOMBIA
# 21          POLAND
# 22        PORTUGAL
# 23         UKRAINE
# 24         AUSTRIA
# 25          GREECE
# 26        MALAYSIA
# 27            DPRK
# 28        THAILAND
# 29          ISRAEL
# 30           CHILE
# 31         BELGIUM
# 32          CANADA
# 33            PERU
# 34         CZECHIA
# 35     SWITZERLAND
# 36    SOUTH AFRICA
# 37     PHILIPPINES
# 38         ROMANIA
# 39         DENMARK
# 40          SWEDEN
# 41            IRAQ
# 42          SERBIA
# 43         HUNGARY
# 44      BANGLADESH
# 45       SINGAPORE
# 46        SLOVAKIA
# ...

# %%
print(df_head["Country,\nOther"].str.lower())
# Out:
# 0              usa
# 1            india
# 2           france
# 3           brazil
# 4          germany
# 5         s. korea
# 6               uk
# 7            italy
# 8            japan
# 9           russia
# 10          turkey
# 11           spain
# 12         vietnam
# 13       australia
# 14       argentina
# 15     netherlands
# 16            iran
# 17          mexico
# 18       indonesia
# 19          taiwan
# 20        colombia
# 21          poland
# 22        portugal
# 23         ukraine
# 24         austria
# 25          greece
# 26        malaysia
# 27            dprk
# 28        thailand
# 29          israel
# 30           chile
# 31         belgium
# 32          canada
# 33            peru
# 34         czechia
# 35     switzerland
# 36    south africa
# 37     philippines
# 38         romania
# 39         denmark
# 40          sweden
# 41            iraq
# 42          serbia
# 43         hungary
# 44      bangladesh
# 45       singapore
# 46        slovakia
# ...

# %%
print(df_head["Country,\nOther"].str.len())
# Out:
# 0      3
# 1      5
# 2      6
# 3      6
# 4      7
# 5      8
# 6      2
# 7      5
# 8      5
# 9      6
# 10     6
# 11     5
# 12     7
# 13     9
# 14     9
# 15    11
# 16     4
# 17     6
# 18     9
# 19     6
# 20     8
# 21     6
# 22     8
# 23     7
# 24     7
# 25     6
# 26     8
# 27     4
# 28     8
# 29     6
# 30     5
# 31     7
# 32     6
# 33     4
# 34     7
# 35    11
# 36    12
# 37    11
# 38     7
# 39     7
# 40     6
# 41     4
# 42     6
# 43     7
# 44    10
# 45     9
# 46     8
# 47     7
# 48    11
# 49     9
# Name: Country,\nOther, dtype: int64

# %%
print(df_head["Country,\nOther"].str.count("a"))
# Out:
# 0     0
# 1     1
# 2     1
# 3     1
# 4     1
# 5     1
# 6     0
# 7     1
# 8     2
# 9     1
# 10    0
# 11    1
# 12    1
# 13    2
# 14    1
# 15    1
# 16    1
# 17    0
# 18    1
# 19    2
# 20    1
# 21    1
# 22    1
# 23    1
# 24    1
# 25    0
# 26    3
# 27    0
# 28    2
# 29    1
# 30    0
# 31    0
# 32    3
# 33    0
# 34    1
# 35    1
# 36    1
# 37    0
# 38    2
# 39    1
# 40    0
# 41    1
# 42    1
# 43    1
# 44    2
# 45    1
# 46    2
# 47    1
# 48    2
# 49    0
# Name: Country,\nOther, dtype: int64

# %%
print(df_head["Country,\nOther"].str.startswith("S"))
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5      True
# 6     False
# 7     False
# 8     False
# 9     False
# 10    False
# 11     True
# 12    False
# 13    False
# 14    False
# 15    False
# 16    False
# 17    False
# 18    False
# 19    False
# 20    False
# 21    False
# 22    False
# 23    False
# 24    False
# 25    False
# 26    False
# 27    False
# 28    False
# 29    False
# 30    False
# 31    False
# 32    False
# 33    False
# 34    False
# 35     True
# 36     True
# 37    False
# 38    False
# 39    False
# 40     True
# 41    False
# 42     True
# 43    False
# 44    False
# 45     True
# 46     True
# 47    False
# 48    False
# 49    False
# Name: Country,\nOther, dtype: bool

# %%
import numpy as np
array1 = np.array([1,5,4,6,7])

# %%
print(array1)
# Out:
# [1 5 4 6 7]

# %%
array1.shape
# Out:
# (5,)
