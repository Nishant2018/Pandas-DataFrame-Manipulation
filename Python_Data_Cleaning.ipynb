# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
import seaborn as sns

# %%
x = pd.read_csv("C:\\Users\\NISHANT\\3D Objects\\CSV_Files\\Covid.csv")

# %%
x
# Out:
#        # Country,\nOther Total\nCases Total\nDeaths  New\nDeaths  \
# 0      1             USA   98,166,904     1,084,282          NaN
# 1      2           India   44,587,307       528,629          NaN
# 2      3          France   35,342,950       155,078          NaN
# 3      4          Brazil   34,706,757       686,027          NaN
# 4      5         Germany   33,312,373       149,948          NaN
# ..   ...             ...          ...           ...          ...
# 225  226            Niue           80           NaN          NaN
# 226  227    Vatican City           29           NaN          NaN
# 227  228          Tuvalu           20           NaN          NaN
# 228  229  Western Sahara           10             1          NaN
# 229  230      MS Zaandam            9             2          NaN
#
#     Total\nRecovered Active\nCases Serious,\nCritical Tot Cases/\n1M pop  \
# 0         94,962,112     2,120,510              2,970            293,206
# ...

# %%
y = x.isnull()
y
# Out:
#          #  Country,\nOther  Total\nCases  Total\nDeaths  New\nDeaths  \
# 0    False            False         False          False         True
# 1    False            False         False          False         True
# 2    False            False         False          False         True
# 3    False            False         False          False         True
# 4    False            False         False          False         True
# ..     ...              ...           ...            ...          ...
# 225  False            False         False           True         True
# 226  False            False         False           True         True
# 227  False            False         False           True         True
# 228  False            False         False          False         True
# 229  False            False         False          False         True
#
#      Total\nRecovered  Active\nCases  Serious,\nCritical  Tot Cases/\n1M pop  \
# ...

# %%
z = x.head(50)

# %%
z
# Out:
#      # Country,\nOther Total\nCases Total\nDeaths  New\nDeaths  \
# 0    1             USA   98,166,904     1,084,282          NaN
# 1    2           India   44,587,307       528,629          NaN
# 2    3          France   35,342,950       155,078          NaN
# 3    4          Brazil   34,706,757       686,027          NaN
# 4    5         Germany   33,312,373       149,948          NaN
# 5    6        S. Korea   24,769,101        28,406         42.0
# 6    7              UK   23,621,952       189,919          NaN
# 7    8           Italy   22,432,803       177,054          NaN
# 8    9           Japan   21,229,216        44,678          NaN
# 9   10          Russia   20,948,470       387,163          NaN
# 10  11          Turkey   16,873,793       101,139          NaN
# 11  12           Spain   13,412,263       114,084          NaN
# 12  13         Vietnam   11,477,886        43,148          NaN
# 13  14       Australia   10,209,239        14,984          NaN
# ...

# %%
z.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 13 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   #                  50 non-null     int64
#  1   Country,
# Other     50 non-null     object
#  2   Total
# Cases        50 non-null     object
#  3   Total
# Deaths       50 non-null     object
#  4   New
# Deaths         2 non-null      float64
#  5   Total
# Recovered    50 non-null     object
#  6   Active
# Cases       50 non-null     object
#  7   Serious,
# Critical  45 non-null     object
#  8   Tot Cases/
# 1M pop  50 non-null     object
#  9   Deaths/
# 1M pop     50 non-null     object
#  10  Total
# Tests        49 non-null     object
#  11  Tests/
# 1M pop      49 non-null     object
#  12  Population         50 non-null     object
# dtypes: float64(1), int64(1), object(11)
# memory usage: 5.2+ KB

# %%
 z["Serious,\nCritical"].fillna(100,inplace=True)
# Out:
# C:\Users\NISHANT\AppData\Local\Temp\ipykernel_24680\4203796189.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   z["Serious,\nCritical"].fillna(100,inplace=True)

# %%
z
# Out:
#      # Country,\nOther Total\nCases Total\nDeaths  New\nDeaths  \
# 0    1             USA   98,166,904     1,084,282          NaN
# 1    2           India   44,587,307       528,629          NaN
# 2    3          France   35,342,950       155,078          NaN
# 3    4          Brazil   34,706,757       686,027          NaN
# 4    5         Germany   33,312,373       149,948          NaN
# 5    6        S. Korea   24,769,101        28,406         42.0
# 6    7              UK   23,621,952       189,919          NaN
# 7    8           Italy   22,432,803       177,054          NaN
# 8    9           Japan   21,229,216        44,678          NaN
# 9   10          Russia   20,948,470       387,163          NaN
# 10  11          Turkey   16,873,793       101,139          NaN
# 11  12           Spain   13,412,263       114,084          NaN
# 12  13         Vietnam   11,477,886        43,148          NaN
# 13  14       Australia   10,209,239        14,984          NaN
# ...

# %%
z.loc[5,'New\nDeaths']=45

# %%
#np.mean(z['Total\nTests'], na.
m = z['Total\nTests'].mean()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In [48], line 2
#       1 #np.mean(z['Total\nTests'], na.
# ----> 2 m = z['Total\nTests'].mean()
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\generic.py:11847, in NDFrame._add_numeric_operations.<locals>.mean(self, axis, skipna, level, numeric_only, **kwargs)
#   11829 @doc(
#   11830     _num_doc,
#   11831     desc="Return the mean of the values over the requested axis.",
#    (...)
#   11845     **kwargs,
#   11846 ):
# > 11847     return NDFrame.mean(self, axis, skipna, level, numeric_only, **kwargs)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\generic.py:11401, in NDFrame.mean(self, axis, skipna, level, numeric_only, **kwargs)
#   11393 def mean(
#   11394     self,
#   11395     axis: Axis | None | lib.NoDefault = lib.no_default,
#    (...)
# ...

# %%
print(z.duplicated())
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10    False
# 11    False
# 12    False
# 13    False
# 14    False
# 15    False
# 16    False
# 17    False
# 18    False
# 19    False
# 20    False
# 21    False
# 22    False
# 23    False
# 24    False
# 25    False
# 26    False
# 27    False
# 28    False
# 29    False
# 30    False
# 31    False
# 32    False
# 33    False
# 34    False
# 35    False
# 36    False
# 37    False
# 38    False
# 39    False
# 40    False
# 41    False
# 42    False
# 43    False
# 44    False
# 45    False
# 46    False
# 47    False
# 48    False
# 49    False
# dtype: bool

# %%
c = z.head(15)

# %%
sns.countplot(x ="Total\nCases",data=c,hue="Country,\nOther")
# Out:
# <AxesSubplot:xlabel='Total\nCases', ylabel='count'>
