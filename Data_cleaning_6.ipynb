# %%
import pandas as pd
import seaborn as sns

# %%
Data =pd.read_csv("C:\\Users\\NISHANT\\3D Objects\\CSV_Files\\Covid.csv")

# %%
pd.options.display.max_rows = 1500

# %%
Data
# Out:
#        #         Country,\nOther Total\nCases Total\nDeaths  New\nDeaths  \
# 0      1                     USA   98,166,904     1,084,282          NaN
# 1      2                   India   44,587,307       528,629          NaN
# 2      3                  France   35,342,950       155,078          NaN
# 3      4                  Brazil   34,706,757       686,027          NaN
# 4      5                 Germany   33,312,373       149,948          NaN
# 5      6                S. Korea   24,769,101        28,406         42.0
# 6      7                      UK   23,621,952       189,919          NaN
# 7      8                   Italy   22,432,803       177,054          NaN
# 8      9                   Japan   21,229,216        44,678          NaN
# 9     10                  Russia   20,948,470       387,163          NaN
# 10    11                  Turkey   16,873,793       101,139          NaN
# 11    12                   Spain   13,412,263       114,084          NaN
# ...

# %%
Data.describe().T
# Out:
#              count   mean        std  min    25%    50%     75%    max
# #            230.0  115.5  66.539462  1.0  58.25  115.5  172.75  230.0
# New\nDeaths    3.0   18.0  21.000000  3.0   6.00    9.0   25.50   42.0

# %%
Data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 230 entries, 0 to 229
# Data columns (total 13 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   #                  230 non-null    int64
#  1   Country,
# Other     230 non-null    object
#  2   Total
# Cases        230 non-null    object
#  3   Total
# Deaths       225 non-null    object
#  4   New
# Deaths         3 non-null      float64
#  5   Total
# Recovered    214 non-null    object
#  6   Active
# Cases       215 non-null    object
#  7   Serious,
# Critical  147 non-null    object
#  8   Tot Cases/
# 1M pop  228 non-null    object
#  9   Deaths/
# 1M pop     223 non-null    object
#  10  Total
# Tests        214 non-null    object
#  11  Tests/
# 1M pop      214 non-null    object
#  12  Population         228 non-null    object
# dtypes: float64(1), int64(1), object(11)
# memory usage: 23.5+ KB

# %%
Data.shape
# Out:
# (230, 13)

# %%
list(Data.columns)
# Out:
# ['#',
#  'Country,\nOther',
#  'Total\nCases',
#  'Total\nDeaths',
#  'New\nDeaths',
#  'Total\nRecovered',
#  'Active\nCases',
#  'Serious,\nCritical',
#  'Tot Cases/\n1M pop',
#  'Deaths/\n1M pop',
#  'Total\nTests',
#  'Tests/\n1M pop',
#  'Population']

# %%
Data.isnull().sum()
# Out:
# #                       0
# Country,\nOther         0
# Total\nCases            0
# Total\nDeaths           5
# New\nDeaths           227
# Total\nRecovered       16
# Active\nCases          15
# Serious,\nCritical     83
# Tot Cases/\n1M pop      2
# Deaths/\n1M pop         7
# Total\nTests           16
# Tests/\n1M pop         16
# Population              2
# dtype: int64

# %%
Data.isnull().sum().sum()
# Out:
# 389

# %%
# Syntax of DataFrame.mean() 
Data.mean(skipna=True, level=None, numeric_only=True)
# Out:
# #              115.5
# New\nDeaths     18.0
# dtype: float64

# %%
Data['Total\nDeaths'] = Data['Total\nDeaths'].fillna(method = 'backfill')

# %%
Data.isnull().sum()
# Out:
# #                       0
# Country,\nOther         0
# Total\nCases            0
# Total\nDeaths           0
# New\nDeaths           227
# Total\nRecovered       16
# Active\nCases          15
# Serious,\nCritical     83
# Tot Cases/\n1M pop      2
# Deaths/\n1M pop         7
# Total\nTests           16
# Tests/\n1M pop         16
# Population              2
# dtype: int64

# %%
Data.duplicated().sum()
# Out:
# 0

# %%
Group = Data.groupby(['Country,\nOther']).groups

# %%
Group
# Out:
# {'Afghanistan': [116], 'Albania': [100], 'Algeria': [104], 'Andorra': [152], 'Angola': [128], 'Anguilla': [216], 'Antigua and Barbuda': [201], 'Argentina': [14], 'Armenia': [94], 'Aruba': [155], 'Australia': [13], 'Austria': [24], 'Azerbaijan': [75], 'Bahamas': [162], 'Bahrain': [78], 'Bangladesh': [44], 'Barbados': [129], 'Belarus': [70], 'Belgium': [31], 'Belize': [141], 'Benin': [169], 'Bermuda': [180], 'Bhutan': [147], 'Bolivia': [65], 'Bosnia and Herzegovina': [95], 'Botswana': [101], 'Brazil': [3], 'British Virgin Islands': [207], 'Brunei': [110], 'Bulgaria': [57], 'Burkina Faso': [173], 'Burundi': [149], 'CAR': [189], 'Cabo Verde': [146], 'Cambodia': [124], 'Cameroon': [126], 'Canada': [32], 'Caribbean Netherlands': [196], 'Cayman Islands': [167], 'Chad': [206], 'Channel Islands': [132], 'Chile': [30], 'China': [107], 'Colombia': [20], 'Comoros': [203], 'Congo': [171], 'Cook Islands': [210], 'Costa Rica': [66], 'Croatia': [59], 'Cuba': [64], 'Curaçao': [153], 'Cyprus': [86], '
# ...

# %%
Data2 = sns.load_dataset("planets")

# %%
Data2
# Out:
#                              method  number  orbital_period      mass  \
# 0                   Radial Velocity       1      269.300000   7.10000
# 1                   Radial Velocity       1      874.774000   2.21000
# 2                   Radial Velocity       1      763.000000   2.60000
# 3                   Radial Velocity       1      326.030000  19.40000
# 4                   Radial Velocity       1      516.220000  10.50000
# 5                   Radial Velocity       1      185.840000   4.80000
# 6                   Radial Velocity       1     1773.400000   4.64000
# 7                   Radial Velocity       1      798.500000       NaN
# 8                   Radial Velocity       1      993.300000  10.30000
# 9                   Radial Velocity       2      452.800000   1.99000
# 10                  Radial Velocity       2      883.000000   0.86000
# 11                  Radial Velocity       1      335.100000   9.88000
# ...

# %%
RevisedData = Data2.head(50)

# %%
RevisedData2 = Data2.tail(50)

# %%
print(pd.merge(RevisedData,RevisedData2,on = 'year'))
# Out:
#                       method_x  number_x  orbital_period_x   mass_x  \
# 0              Radial Velocity         1         269.30000   7.1000
# 1                      Imaging         1               NaN      NaN
# 2              Radial Velocity         1         874.77400   2.2100
# 3              Radial Velocity         1         874.77400   2.2100
# 4              Radial Velocity         1         185.84000   4.8000
# 5              Radial Velocity         1         185.84000   4.8000
# 6              Radial Velocity         1         993.30000  10.3000
# 7              Radial Velocity         1         993.30000  10.3000
# 8              Radial Velocity         1         479.10000   3.8800
# 9              Radial Velocity         1         479.10000   3.8800
# 10             Radial Velocity         1         952.70000   5.3000
# 11             Radial Velocity         1         952.70000   5.3000
# 12                     Imaging         1               NaN      NaN
# ...

# %%
Data2['method'].str.lower()
# Out:
# 0                     radial velocity
# 1                     radial velocity
# 2                     radial velocity
# 3                     radial velocity
# 4                     radial velocity
# 5                     radial velocity
# 6                     radial velocity
# 7                     radial velocity
# 8                     radial velocity
# 9                     radial velocity
# 10                    radial velocity
# 11                    radial velocity
# 12                    radial velocity
# 13                    radial velocity
# 14                    radial velocity
# 15                    radial velocity
# 16                    radial velocity
# 17                    radial velocity
# 18                    radial velocity
# 19                    radial velocity
# 20                    radial velocity
# 21                    radial velocity
# 22                    radial velocity
# 23                    radial velocity
# 24                    radial velocity
# ...

# %%
Data2['method'].str.upper()
# Out:
# 0                     RADIAL VELOCITY
# 1                     RADIAL VELOCITY
# 2                     RADIAL VELOCITY
# 3                     RADIAL VELOCITY
# 4                     RADIAL VELOCITY
# 5                     RADIAL VELOCITY
# 6                     RADIAL VELOCITY
# 7                     RADIAL VELOCITY
# 8                     RADIAL VELOCITY
# 9                     RADIAL VELOCITY
# 10                    RADIAL VELOCITY
# 11                    RADIAL VELOCITY
# 12                    RADIAL VELOCITY
# 13                    RADIAL VELOCITY
# 14                    RADIAL VELOCITY
# 15                    RADIAL VELOCITY
# 16                    RADIAL VELOCITY
# 17                    RADIAL VELOCITY
# 18                    RADIAL VELOCITY
# 19                    RADIAL VELOCITY
# 20                    RADIAL VELOCITY
# 21                    RADIAL VELOCITY
# 22                    RADIAL VELOCITY
# 23                    RADIAL VELOCITY
# 24                    RADIAL VELOCITY
# ...

# %%
Data2['method'].str.len()
# Out:
# 0       15
# 1       15
# 2       15
# 3       15
# 4       15
# 5       15
# 6       15
# 7       15
# 8       15
# 9       15
# 10      15
# 11      15
# 12      15
# 13      15
# 14      15
# 15      15
# 16      15
# 17      15
# 18      15
# 19      15
# 20      15
# 21      15
# 22      15
# 23      15
# 24      15
# 25      15
# 26      15
# 27      15
# 28      15
# 29       7
# 30       7
# 31       7
# 32      25
# 33       7
# 34       7
# 35       7
# 36       7
# 37      25
# 38      25
# 39      25
# 40      25
# 41      25
# 42      25
# 43      25
# 44      25
# 45      15
# 46      15
# 47       7
# 48      15
# 49      15
# 50      15
# 51      15
# 52      15
# 53      15
# 54       7
# 55      15
# 56      15
# 57      15
# 58      15
# 59      15
# 60      15
# 61      15
# 62      15
# 63      15
# 64      15
# 65      15
# 66      15
# 67      15
# 68       7
# 69       7
# 70       7
# 71       7
# 72       7
# 73       7
# 74       7
# 75       7
# ...

# %%
Data2['method'].str.startswith('R').sum()
# Out:
# 553

# %%
Data2['method'].str.endswith('y').sum()
# Out:
# 555

# %%
Data2['method'].str.islower()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
# 5       False
# 6       False
# 7       False
# 8       False
# 9       False
# 10      False
# 11      False
# 12      False
# 13      False
# 14      False
# 15      False
# 16      False
# 17      False
# 18      False
# 19      False
# 20      False
# 21      False
# 22      False
# 23      False
# 24      False
# 25      False
# 26      False
# 27      False
# 28      False
# 29      False
# 30      False
# 31      False
# 32      False
# 33      False
# 34      False
# 35      False
# 36      False
# 37      False
# 38      False
# 39      False
# 40      False
# 41      False
# 42      False
# 43      False
# 44      False
# 45      False
# 46      False
# 47      False
# 48      False
# 49      False
# 50      False
# 51      False
# 52      False
# 53      False
# 54      False
# 55      False
# 56      False
# 57      False
# 58      False
# 59      False
# 60      False
# 61      False
# ...
