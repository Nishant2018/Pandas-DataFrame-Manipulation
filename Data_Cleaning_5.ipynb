# %%
import pandas as pd

# %%
Data = pd.read_csv("C:\\Users\\NISHANT\\3D Objects\\CSV_Files\\Covid.csv")

# %%
pd.options.display.max_rows = 500

# %%
Data
# Out:
#        #         Country,\nOther Total\nCases Total\nDeaths  New\nDeaths  \
# 0      1                     USA   98,166,904     1,084,282          NaN
# 1      2                   India   44,587,307       528,629          NaN
# 2      3                  France   35,342,950       155,078          NaN
# 3      4                  Brazil   34,706,757       686,027          NaN
# 4      5                 Germany   33,312,373       149,948          NaN
# 5      6                S. Korea   24,769,101        28,406         42.0
# 6      7                      UK   23,621,952       189,919          NaN
# 7      8                   Italy   22,432,803       177,054          NaN
# 8      9                   Japan   21,229,216        44,678          NaN
# 9     10                  Russia   20,948,470       387,163          NaN
# 10    11                  Turkey   16,873,793       101,139          NaN
# 11    12                   Spain   13,412,263       114,084          NaN
# ...

# %%
Data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 230 entries, 0 to 229
# Data columns (total 13 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   #                  230 non-null    int64
#  1   Country,
# Other     230 non-null    object
#  2   Total
# Cases        230 non-null    object
#  3   Total
# Deaths       225 non-null    object
#  4   New
# Deaths         3 non-null      float64
#  5   Total
# Recovered    214 non-null    object
#  6   Active
# Cases       215 non-null    object
#  7   Serious,
# Critical  147 non-null    object
#  8   Tot Cases/
# 1M pop  228 non-null    object
#  9   Deaths/
# 1M pop     223 non-null    object
#  10  Total
# Tests        214 non-null    object
#  11  Tests/
# 1M pop      214 non-null    object
#  12  Population         228 non-null    object
# dtypes: float64(1), int64(1), object(11)
# memory usage: 23.5+ KB

# %%
Data.describe().T
# Out:
#              count   mean        std  min    25%    50%     75%    max
# #            230.0  115.5  66.539462  1.0  58.25  115.5  172.75  230.0
# New\nDeaths    3.0   18.0  21.000000  3.0   6.00    9.0   25.50   42.0

# %%
list(Data.columns)
# Out:
# ['#',
#  'Country,\nOther',
#  'Total\nCases',
#  'Total\nDeaths',
#  'New\nDeaths',
#  'Total\nRecovered',
#  'Active\nCases',
#  'Serious,\nCritical',
#  'Tot Cases/\n1M pop',
#  'Deaths/\n1M pop',
#  'Total\nTests',
#  'Tests/\n1M pop',
#  'Population']

# %%
Analyse_data = Data.copy()

# %%
Analyse_data
# Out:
#        #         Country,\nOther Total\nCases Total\nDeaths  New\nDeaths  \
# 0      1                     USA   98,166,904     1,084,282          NaN
# 1      2                   India   44,587,307       528,629          NaN
# 2      3                  France   35,342,950       155,078          NaN
# 3      4                  Brazil   34,706,757       686,027          NaN
# 4      5                 Germany   33,312,373       149,948          NaN
# 5      6                S. Korea   24,769,101        28,406         42.0
# 6      7                      UK   23,621,952       189,919          NaN
# 7      8                   Italy   22,432,803       177,054          NaN
# 8      9                   Japan   21,229,216        44,678          NaN
# 9     10                  Russia   20,948,470       387,163          NaN
# 10    11                  Turkey   16,873,793       101,139          NaN
# 11    12                   Spain   13,412,263       114,084          NaN
# ...

# %%
Analyse_data.isnull().sum()
# Out:
# #                       0
# Country,\nOther         0
# Total\nCases            0
# Total\nDeaths           5
# New\nDeaths           227
# Total\nRecovered       16
# Active\nCases          15
# Serious,\nCritical     83
# Tot Cases/\n1M pop      2
# Deaths/\n1M pop         7
# Total\nTests           16
# Tests/\n1M pop         16
# Population              2
# dtype: int64

# %%
Analyse_data.drop(["New\nDeaths"],axis =1)
# Out:
#        #         Country,\nOther Total\nCases Total\nDeaths Total\nRecovered  \
# 0      1                     USA   98,166,904     1,084,282       94,962,112
# 1      2                   India   44,587,307       528,629       44,019,095
# 2      3                  France   35,342,950       155,078       34,527,115
# 3      4                  Brazil   34,706,757       686,027       33,838,636
# 4      5                 Germany   33,312,373       149,948       32,315,200
# 5      6                S. Korea   24,769,101        28,406       24,013,461
# 6      7                      UK   23,621,952       189,919       23,347,871
# 7      8                   Italy   22,432,803       177,054       21,779,604
# 8      9                   Japan   21,229,216        44,678       20,380,089
# 9     10                  Russia   20,948,470       387,163       19,979,763
# 10    11                  Turkey   16,873,793       101,139       16,754,301
# ...

# %%
Analyse_data.shape[1]
# Out:
# 13

# %%
Data.shape[1]
# Out:
# 13

# %%
mean = Analyse_data["Total\nDeaths"].mean(axis = 0, skipna = False)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In [22], line 1
# ----> 1 mean = Analyse_data["Total\nDeaths"].mean(axis = 0, skipna = False)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\generic.py:11847, in NDFrame._add_numeric_operations.<locals>.mean(self, axis, skipna, level, numeric_only, **kwargs)
#   11829 @doc(
#   11830     _num_doc,
#   11831     desc="Return the mean of the values over the requested axis.",
#    (...)
#   11845     **kwargs,
#   11846 ):
# > 11847     return NDFrame.mean(self, axis, skipna, level, numeric_only, **kwargs)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\generic.py:11401, in NDFrame.mean(self, axis, skipna, level, numeric_only, **kwargs)
#   11393 def mean(
#   11394     self,
#   11395     axis: Axis | None | lib.NoDefault = lib.no_default,
#    (...)
# ...
