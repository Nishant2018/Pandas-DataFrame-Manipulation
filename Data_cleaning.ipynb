# %%
import pandas as pd
import seaborn as sns
from matplotlib import pyplot as plt
import numpy as np

# %%
Data = pd.read_csv("C:\\Users\\NISHANT\\3D Objects\\CSV_Files\\Covid.csv")

# %%
Data
# Out:
#        # Country,\nOther Total\nCases Total\nDeaths  New\nDeaths  \
# 0      1             USA   98,166,904     1,084,282          NaN
# 1      2           India   44,587,307       528,629          NaN
# 2      3          France   35,342,950       155,078          NaN
# 3      4          Brazil   34,706,757       686,027          NaN
# 4      5         Germany   33,312,373       149,948          NaN
# ..   ...             ...          ...           ...          ...
# 225  226            Niue           80           NaN          NaN
# 226  227    Vatican City           29           NaN          NaN
# 227  228          Tuvalu           20           NaN          NaN
# 228  229  Western Sahara           10             1          NaN
# 229  230      MS Zaandam            9             2          NaN
#
#     Total\nRecovered Active\nCases Serious,\nCritical Tot Cases/\n1M pop  \
# 0         94,962,112     2,120,510              2,970            293,206
# ...

# %%
Data_50 = Data.head(50)

# %%
Data_50
# Out:
#      # Country,\nOther Total\nCases Total\nDeaths  New\nDeaths  \
# 0    1             USA   98,166,904     1,084,282          NaN
# 1    2           India   44,587,307       528,629          NaN
# 2    3          France   35,342,950       155,078          NaN
# 3    4          Brazil   34,706,757       686,027          NaN
# 4    5         Germany   33,312,373       149,948          NaN
# 5    6        S. Korea   24,769,101        28,406         42.0
# 6    7              UK   23,621,952       189,919          NaN
# 7    8           Italy   22,432,803       177,054          NaN
# 8    9           Japan   21,229,216        44,678          NaN
# 9   10          Russia   20,948,470       387,163          NaN
# 10  11          Turkey   16,873,793       101,139          NaN
# 11  12           Spain   13,412,263       114,084          NaN
# 12  13         Vietnam   11,477,886        43,148          NaN
# 13  14       Australia   10,209,239        14,984          NaN
# ...

# %%
Data_last_50 = Data.tail(50)
Data_last_50
# Out:
#        #         Country,\nOther Total\nCases Total\nDeaths  New\nDeaths  \
# 180  181                 Bermuda       18,154           148          NaN
# 181  182             South Sudan       17,823           138          NaN
# 182  183              Tajikistan       17,786           125          NaN
# 183  184       Equatorial Guinea       17,012           183          NaN
# 184  185                   Tonga       16,182            12          NaN
# 185  186                   Samoa       15,925            29          NaN
# 186  187                Dominica       15,747            74          NaN
# 187  188                Djibouti       15,690           189          NaN
# 188  189        Marshall Islands       15,275            17          NaN
# 189  190                     CAR       14,913           113          NaN
# 190  191                  Monaco       14,608            63          NaN
# 191  192                  Gambia       12,508           372          NaN
# ...

# %%
Data_50.isnull()
# Out:
#         #  Country,\nOther  Total\nCases  Total\nDeaths  New\nDeaths  \
# 0   False            False         False          False         True
# 1   False            False         False          False         True
# 2   False            False         False          False         True
# 3   False            False         False          False         True
# 4   False            False         False          False         True
# 5   False            False         False          False        False
# 6   False            False         False          False         True
# 7   False            False         False          False         True
# 8   False            False         False          False         True
# 9   False            False         False          False         True
# 10  False            False         False          False         True
# 11  False            False         False          False         True
# 12  False            False         False          False         True
# ...

# %%
Data_50.dropna()
# Out:
#      # Country,\nOther Total\nCases Total\nDeaths  New\nDeaths  \
# 5    6        S. Korea   24,769,101        28,406         42.0
# 28  29        Thailand    4,681,309        32,767          9.0
#
#    Total\nRecovered Active\nCases Serious,\nCritical Tot Cases/\n1M pop  \
# 5        24,013,461       727,234                352            482,547
# 28        4,642,083         6,459              1,496             66,801
#
#    Deaths/\n1M pop Total\nTests Tests/\n1M pop  Population
# 5              553   15,804,065        307,892  51,329,899
# 28             468   17,270,775        246,450  70,078,203

# %%
Data_50["Serious,\nCritical"].dropna()
# Out:
# 0     2,970
# 1       698
# 2       869
# 3     8,318
# 4     1,406
# 5       352
# 6       146
# 7       141
# 8       204
# 9     2,300
# 10      975
# 11      339
# 12      106
# 13       49
# 14      294
# 15       35
# 16      157
# 17    4,798
# 18    2,771
# 20      342
# 21    3,086
# 22       61
# 23      177
# 24       47
# 25      115
# 26       43
# 28    1,496
# 29      101
# 30      124
# 31       48
# 32       99
# 33      147
# 34       39
# 35       54
# 36      192
# 37      696
# 38      123
# 40       13
# 41       21
# 42       33
# 43       18
# 44    1,331
# 45        9
# 46       22
# 49        8
# Name: Serious,\nCritical, dtype: object

# %%
Data_50.dropna(inplace=True)
# Out:
# C:\Users\NISHANT\AppData\Local\Temp\ipykernel_17836\1588930013.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Data_50.dropna(inplace=True)

# %%
Data_50
# Out:
#      # Country,\nOther Total\nCases Total\nDeaths  New\nDeaths  \
# 5    6        S. Korea   24,769,101        28,406         42.0
# 28  29        Thailand    4,681,309        32,767          9.0
#
#    Total\nRecovered Active\nCases Serious,\nCritical Tot Cases/\n1M pop  \
# 5        24,013,461       727,234                352            482,547
# 28        4,642,083         6,459              1,496             66,801
#
#    Deaths/\n1M pop Total\nTests Tests/\n1M pop  Population
# 5              553   15,804,065        307,892  51,329,899
# 28             468   17,270,775        246,450  70,078,203

# %%
Data_above_50 = Data.head(50)

# %%
Data_above_50
# Out:
#      # Country,\nOther Total\nCases Total\nDeaths  New\nDeaths  \
# 0    1             USA   98,166,904     1,084,282          NaN
# 1    2           India   44,587,307       528,629          NaN
# 2    3          France   35,342,950       155,078          NaN
# 3    4          Brazil   34,706,757       686,027          NaN
# 4    5         Germany   33,312,373       149,948          NaN
# 5    6        S. Korea   24,769,101        28,406         42.0
# 6    7              UK   23,621,952       189,919          NaN
# 7    8           Italy   22,432,803       177,054          NaN
# 8    9           Japan   21,229,216        44,678          NaN
# 9   10          Russia   20,948,470       387,163          NaN
# 10  11          Turkey   16,873,793       101,139          NaN
# 11  12           Spain   13,412,263       114,084          NaN
# 12  13         Vietnam   11,477,886        43,148          NaN
# 13  14       Australia   10,209,239        14,984          NaN
# ...

# %%
Data_above_50["Tests/\n1M pop"].fillna(1523511,inplace=True)
# Out:
# C:\Users\NISHANT\AppData\Local\Temp\ipykernel_17836\3364316607.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Data_above_50["Tests/\n1M pop"].fillna(1523511,inplace=True)

# %%
Data_above_50
# Out:
#      # Country,\nOther Total\nCases Total\nDeaths  New\nDeaths  \
# 0    1             USA   98,166,904     1,084,282          NaN
# 1    2           India   44,587,307       528,629          NaN
# 2    3          France   35,342,950       155,078          NaN
# 3    4          Brazil   34,706,757       686,027          NaN
# 4    5         Germany   33,312,373       149,948          NaN
# 5    6        S. Korea   24,769,101        28,406         42.0
# 6    7              UK   23,621,952       189,919          NaN
# 7    8           Italy   22,432,803       177,054          NaN
# 8    9           Japan   21,229,216        44,678          NaN
# 9   10          Russia   20,948,470       387,163          NaN
# 10  11          Turkey   16,873,793       101,139          NaN
# 11  12           Spain   13,412,263       114,084          NaN
# 12  13         Vietnam   11,477,886        43,148          NaN
# 13  14       Australia   10,209,239        14,984          NaN
# ...

# %%
Data_above_50["Total\nTests"]
# Out:
# 0     1,118,158,870
# 1       894,416,853
# 2       271,490,188
# 3        63,776,166
# 4       122,332,384
# 5        15,804,065
# 6       522,526,476
# 7       246,636,495
# 8        76,201,407
# 9       273,400,000
# 10      162,743,369
# 11      471,036,328
# 12       85,826,548
# 13       78,835,048
# 14       35,716,069
# 15       21,107,399
# 16       54,095,556
# 17       18,393,211
# 18      108,656,989
# 19       25,998,416
# 20       36,572,720
# 21       37,335,609
# 22       44,988,307
# 23       19,521,252
# 24      197,543,761
# 25       94,139,966
# 26       64,604,259
# 27              NaN
# 28       17,270,775
# 29       41,373,364
# 30       45,128,974
# 31       35,555,508
# 32       64,928,884
# 33       35,126,382
# 34       56,212,735
# 35       22,318,542
# 36       26,174,429
# 37       32,796,350
# 38       25,094,131
# 39      128,397,719
# 40       18,965,590
# 41       19,239,264
# 42       11,030,499
# 43       11,394,556
# 44       14,872,260
# ...

# %%
arr2=np.nanmean(Data_above_50["Total\nTests"])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In [24], line 1
# ----> 1 arr2=np.nanmean(Data_above_50["Total\nTests"])
#
# File <__array_function__ internals>:180, in nanmean(*args, **kwargs)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\numpy\lib\nanfunctions.py:1046, in nanmean(a, axis, dtype, out, keepdims, where)
#    1042     raise TypeError("If a is inexact, then out must be inexact")
#    1044 cnt = np.sum(~mask, axis=axis, dtype=np.intp, keepdims=keepdims,
#    1045              where=where)
# -> 1046 tot = np.sum(arr, axis=axis, dtype=dtype, out=out, keepdims=keepdims,
#    1047              where=where)
#    1048 avg = _divide_by_count(tot, cnt, out=out)
#    1050 isbad = (cnt == 0)
#
# File <__array_function__ internals>:180, in sum(*args, **kwargs)
#
# ...
