# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
import seaborn as sns

# %%
pd.options.display.max_rows = 1050
#%load_ext google.colab.data_table

# %%
Data = sns.load_dataset("planets")

# %%
display(Data)
# Out:
#                              method  number  orbital_period      mass  \
# 0                   Radial Velocity       1      269.300000   7.10000
# 1                   Radial Velocity       1      874.774000   2.21000
# 2                   Radial Velocity       1      763.000000   2.60000
# 3                   Radial Velocity       1      326.030000  19.40000
# 4                   Radial Velocity       1      516.220000  10.50000
# 5                   Radial Velocity       1      185.840000   4.80000
# 6                   Radial Velocity       1     1773.400000   4.64000
# 7                   Radial Velocity       1      798.500000       NaN
# 8                   Radial Velocity       1      993.300000  10.30000
# 9                   Radial Velocity       2      452.800000   1.99000
# 10                  Radial Velocity       2      883.000000   0.86000
# 11                  Radial Velocity       1      335.100000   9.88000
# ...

# %%
Data.describe().T
# Out:
#                  count         mean           std          min         25%  \
# number          1035.0     1.785507      1.240976     1.000000     1.00000
# orbital_period   992.0  2002.917596  26014.728304     0.090706     5.44254
# mass             513.0     2.638161      3.818617     0.003600     0.22900
# distance         808.0   264.069282    733.116493     1.350000    32.56000
# year            1035.0  2009.070531      3.972567  1989.000000  2007.00000
#
#                       50%       75%       max
# number             1.0000     2.000       7.0
# orbital_period    39.9795   526.005  730000.0
# mass               1.2600     3.040      25.0
# distance          55.2500   178.500    8500.0
# year            2010.0000  2012.000    2014.0

# %%
Data_2 = Data.copy()

# %%
Data_2
# Out:
#                              method  number  orbital_period      mass  \
# 0                   Radial Velocity       1      269.300000   7.10000
# 1                   Radial Velocity       1      874.774000   2.21000
# 2                   Radial Velocity       1      763.000000   2.60000
# 3                   Radial Velocity       1      326.030000  19.40000
# 4                   Radial Velocity       1      516.220000  10.50000
# 5                   Radial Velocity       1      185.840000   4.80000
# 6                   Radial Velocity       1     1773.400000   4.64000
# 7                   Radial Velocity       1      798.500000       NaN
# 8                   Radial Velocity       1      993.300000  10.30000
# 9                   Radial Velocity       2      452.800000   1.99000
# 10                  Radial Velocity       2      883.000000   0.86000
# 11                  Radial Velocity       1      335.100000   9.88000
# ...

# %%
Revised_data = Data_2.head(25)
Revised_data
# Out:
#              method  number  orbital_period    mass  distance  year
# 0   Radial Velocity       1      269.300000   7.100     77.40  2006
# 1   Radial Velocity       1      874.774000   2.210     56.95  2008
# 2   Radial Velocity       1      763.000000   2.600     19.84  2011
# 3   Radial Velocity       1      326.030000  19.400    110.62  2007
# 4   Radial Velocity       1      516.220000  10.500    119.47  2009
# 5   Radial Velocity       1      185.840000   4.800     76.39  2008
# 6   Radial Velocity       1     1773.400000   4.640     18.15  2002
# 7   Radial Velocity       1      798.500000     NaN     21.41  1996
# 8   Radial Velocity       1      993.300000  10.300     73.10  2008
# 9   Radial Velocity       2      452.800000   1.990     74.79  2010
# 10  Radial Velocity       2      883.000000   0.860     74.79  2010
# 11  Radial Velocity       1      335.100000   9.880     39.43  2009
# 12  Radial Velocity       1      479.100000   3.880     97.28  2008
# ...

# %%
Revised_data_2 = Data_2.tail(25)
Revised_data_2
# Out:
#        method  number  orbital_period  mass  distance  year
# 1010  Transit       1        7.919585   NaN     125.0  2012
# 1011  Transit       1        4.305001   NaN     400.0  2012
# 1012  Transit       1        3.855900   NaN     480.0  2012
# 1013  Transit       1        4.411953   NaN     160.0  2012
# 1014  Transit       1        4.378090   NaN     330.0  2012
# 1015  Transit       1        1.573292   NaN     350.0  2012
# 1016  Transit       1        2.311424   NaN     310.0  2013
# 1017  Transit       1        4.086052   NaN     380.0  2012
# 1018  Transit       1        4.614420   NaN     225.0  2012
# 1019  Transit       1        2.903675   NaN     345.0  2012
# 1020  Transit       1        2.216742   NaN     340.0  2012
# 1021  Transit       1        2.484193   NaN     260.0  2013
# 1022  Transit       1        1.360031   NaN      93.0  2012
# 1023  Transit       1        2.175176   NaN     550.0  2012
# 1024  Transit       1        3.662387   NaN     240.0  2012
# ...

# %%
Revised_data.isnull()
# Out:
#     method  number  orbital_period   mass  distance   year
# 0    False   False           False  False     False  False
# 1    False   False           False  False     False  False
# 2    False   False           False  False     False  False
# 3    False   False           False  False     False  False
# 4    False   False           False  False     False  False
# 5    False   False           False  False     False  False
# 6    False   False           False  False     False  False
# 7    False   False           False   True     False  False
# 8    False   False           False  False     False  False
# 9    False   False           False  False     False  False
# 10   False   False           False  False     False  False
# 11   False   False           False  False     False  False
# 12   False   False           False  False     False  False
# 13   False   False           False  False     False  False
# 14   False   False           False  False     False  False
# ...

# %%
Revised_data.isnull().sum()
# Out:
# method            0
# number            0
# orbital_period    0
# mass              2
# distance          0
# year              0
# dtype: int64

# %%
mean=Revised_data["mass"].mean()
mean
# Out:
# 3.832782608695652

# %%
Revised_data.fillna(mean,inplace=True)
Revised_data
# Out:
# C:\Users\NISHANT\AppData\Local\Temp\ipykernel_16064\969744631.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Revised_data.fillna(mean,inplace=True)
#              method  number  orbital_period       mass  distance  year
# 0   Radial Velocity       1      269.300000   7.100000     77.40  2006
# 1   Radial Velocity       1      874.774000   2.210000     56.95  2008
# 2   Radial Velocity       1      763.000000   2.600000     19.84  2011
# 3   Radial Velocity       1      326.030000  19.400000    110.62  2007
# 4   Radial Velocity       1      516.220000  10.500000    119.47  2009
# 5   Radial Velocity       1      185.840000   4.800000     76.39  2008
# 6   Radial Velocity       1     1773.400000   4.640000     18.15  2002
# ...

# %%
Revised_data.corr()
# Out:
# C:\Users\NISHANT\AppData\Local\Temp\ipykernel_16064\525272178.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   Revised_data.corr()
#                   number  orbital_period      mass  distance      year
# number          1.000000        0.135698 -0.483765 -0.604131 -0.125553
# orbital_period  0.135698        1.000000 -0.094590 -0.191013  0.041977
# mass           -0.483765       -0.094590  1.000000  0.682348  0.173719
# distance       -0.604131       -0.191013  0.682348  1.000000  0.362160
# year           -0.125553        0.041977  0.173719  0.362160  1.000000

# %%
Revised_data_2.isnull()
# Out:
#       method  number  orbital_period  mass  distance   year
# 1010   False   False           False  True     False  False
# 1011   False   False           False  True     False  False
# 1012   False   False           False  True     False  False
# 1013   False   False           False  True     False  False
# 1014   False   False           False  True     False  False
# 1015   False   False           False  True     False  False
# 1016   False   False           False  True     False  False
# 1017   False   False           False  True     False  False
# 1018   False   False           False  True     False  False
# 1019   False   False           False  True     False  False
# 1020   False   False           False  True     False  False
# 1021   False   False           False  True     False  False
# 1022   False   False           False  True     False  False
# 1023   False   False           False  True     False  False
# 1024   False   False           False  True     False  False
# ...

# %%
Revised_data_2.isnull().sum()
# Out:
# method             0
# number             0
# orbital_period     2
# mass              25
# distance           0
# year               0
# dtype: int64

# %%
mean_2=Revised_data["orbital_period"].mean()
mean_2
# Out:
# 1260.8323329999998

# %%
Revised_data_2["orbital_period"].fillna(mean_2,inplace=True)
# Out:
# C:\Users\NISHANT\AppData\Local\Temp\ipykernel_16064\3278067874.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Revised_data_2["orbital_period"].fillna(mean_2,inplace=True)

# %%
Revised_data_2
# Out:
#        method  number  orbital_period  mass  distance  year
# 1010  Transit       1        7.919585   NaN     125.0  2012
# 1011  Transit       1        4.305001   NaN     400.0  2012
# 1012  Transit       1        3.855900   NaN     480.0  2012
# 1013  Transit       1        4.411953   NaN     160.0  2012
# 1014  Transit       1        4.378090   NaN     330.0  2012
# 1015  Transit       1        1.573292   NaN     350.0  2012
# 1016  Transit       1        2.311424   NaN     310.0  2013
# 1017  Transit       1        4.086052   NaN     380.0  2012
# 1018  Transit       1        4.614420   NaN     225.0  2012
# 1019  Transit       1        2.903675   NaN     345.0  2012
# 1020  Transit       1        2.216742   NaN     340.0  2012
# 1021  Transit       1        2.484193   NaN     260.0  2013
# 1022  Transit       1        1.360031   NaN      93.0  2012
# 1023  Transit       1        2.175176   NaN     550.0  2012
# 1024  Transit       1        3.662387   NaN     240.0  2012
# ...

# %%
Hole_mean = Data["mass"].mean()
Hole_mean
# Out:
# 2.6381605847953216

# %%
Revised_data_2["mass"].fillna(Hole_mean,inplace=True)
# Out:
# C:\Users\NISHANT\AppData\Local\Temp\ipykernel_16064\3757119901.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Revised_data_2["mass"].fillna(Hole_mean,inplace=True)

# %%
Revised_data_2
# Out:
#        method  number  orbital_period      mass  distance  year
# 1010  Transit       1        7.919585  2.638161     125.0  2012
# 1011  Transit       1        4.305001  2.638161     400.0  2012
# 1012  Transit       1        3.855900  2.638161     480.0  2012
# 1013  Transit       1        4.411953  2.638161     160.0  2012
# 1014  Transit       1        4.378090  2.638161     330.0  2012
# 1015  Transit       1        1.573292  2.638161     350.0  2012
# 1016  Transit       1        2.311424  2.638161     310.0  2013
# 1017  Transit       1        4.086052  2.638161     380.0  2012
# 1018  Transit       1        4.614420  2.638161     225.0  2012
# 1019  Transit       1        2.903675  2.638161     345.0  2012
# 1020  Transit       1        2.216742  2.638161     340.0  2012
# 1021  Transit       1        2.484193  2.638161     260.0  2013
# 1022  Transit       1        1.360031  2.638161      93.0  2012
# 1023  Transit       1        2.175176  2.638161     550.0  2012
# ...

# %%
Data.isnull().sum()
# Out:
# method              0
# number              0
# orbital_period     43
# mass              522
# distance          227
# year                0
# dtype: int64

# %%
Data["orbital_period"].fillna(2002.917596,inplace=True)

# %%
Data["mass"].fillna(2.638161,inplace=True)

# %%
Data["distance"].fillna(264.069282,inplace=True)

# %%
Data.isnull().sum()
# Out:
# method            0
# number            0
# orbital_period    0
# mass              0
# distance          0
# year              0
# dtype: int64

# %%
Data
# Out:
#                              method  number  orbital_period       mass  \
# 0                   Radial Velocity       1      269.300000   7.100000
# 1                   Radial Velocity       1      874.774000   2.210000
# 2                   Radial Velocity       1      763.000000   2.600000
# 3                   Radial Velocity       1      326.030000  19.400000
# 4                   Radial Velocity       1      516.220000  10.500000
# 5                   Radial Velocity       1      185.840000   4.800000
# 6                   Radial Velocity       1     1773.400000   4.640000
# 7                   Radial Velocity       1      798.500000   2.638161
# 8                   Radial Velocity       1      993.300000  10.300000
# 9                   Radial Velocity       2      452.800000   1.990000
# 10                  Radial Velocity       2      883.000000   0.860000
# 11                  Radial Velocity       1      335.100000   9.880000
# ...

# %%
Data.duplicated().sum()
# Out:
# 4

# %%
Data.drop_duplicates(inplace=True)

# %%
Data.duplicated().sum()
# Out:
# 0

# %%
Data.shape
# Out:
# (1031, 6)

# %%
print(pd.Series(Data.groupby(["method","year"]).groups))
# Out:
# Astrometry                     2010                     Int64Index([537], dtype='int64')
#                                2013                     Int64Index([113], dtype='int64')
# Eclipse Timing Variations      2008                  Int64Index([37, 38], dtype='int64')
#                                2009                      Int64Index([32], dtype='int64')
#                                2010                  Int64Index([39, 40], dtype='int64')
#                                2011              Int64Index([41, 43, 44], dtype='int64')
#                                2012                      Int64Index([42], dtype='int64')
# Imaging                        2004              Int64Index([31, 35, 73], dtype='int64')
#                                2005                      Int64Index([29], dtype='int64')
#                                2006        Int64Index([36, 90, 577, 937], dtype='int64')
# ...

# %%
group = Data.groupby("year")
print(group.get_group(2004))
# Out:
#               method  number  orbital_period      mass     distance  year
# 18   Radial Velocity       5       44.380000  0.165000    12.530000  2004
# 31           Imaging       1     2002.917596  2.638161   140.000000  2004
# 35           Imaging       1     2002.917596  2.638161   139.000000  2004
# 73           Imaging       1     2002.917596  2.638161    52.400000  2004
# 123  Radial Velocity       1        2.643850  2.638161    10.230000  2004
# 300  Radial Velocity       2       55.000000  2.300000    42.880000  2004
# 316  Radial Velocity       1      963.000000  2.540000    43.030000  2004
# 327  Radial Velocity       1      890.760000  1.790000    48.950000  2004
# 384  Radial Velocity       1        3.416000  0.220000    74.460000  2004
# 403  Radial Velocity       2       17.054000  0.087000    17.990000  2004
# 445  Radial Velocity       1     2597.000000  1.880000    33.010000  2004
# 446  Radial Velocity       1       25.827000  0.178000    38.020000  2004
# ...

# %%
print(pd.merge(Revised_data,Revised_data_2,on=["year"]))
# Out:
#            method_x  number_x  orbital_period_x     mass_x  distance_x  year  \
# 0   Radial Velocity         1         269.30000   7.100000       77.40  2006
# 1   Radial Velocity         1         874.77400   2.210000       56.95  2008
# 2   Radial Velocity         1         874.77400   2.210000       56.95  2008
# 3   Radial Velocity         1         185.84000   4.800000       76.39  2008
# 4   Radial Velocity         1         185.84000   4.800000       76.39  2008
# 5   Radial Velocity         1         993.30000  10.300000       73.10  2008
# 6   Radial Velocity         1         993.30000  10.300000       73.10  2008
# 7   Radial Velocity         1         479.10000   3.880000       97.28  2008
# 8   Radial Velocity         1         479.10000   3.880000       97.28  2008
# 9   Radial Velocity         1         763.00000   2.600000       19.84  2011
# 10  Radial Velocity         5           0.73654   3.832783       12.53  2011
# ...

# %%
Data.sort_values(by="year")
# Out:
#                              method  number  orbital_period       mass  \
# 441                 Radial Velocity       1       83.888000  11.680000
# 942                   Pulsar Timing       3       66.541900   2.638161
# 941                   Pulsar Timing       3       25.262000   2.638161
# 943                   Pulsar Timing       3       98.211400   2.638161
# 16                  Radial Velocity       1        4.230785   0.472000
# 64                  Radial Velocity       4        4.617033   0.687600
# 62                  Radial Velocity       1        3.313500   3.900000
# 7                   Radial Velocity       1      798.500000   2.638161
# 25                  Radial Velocity       1      116.688400   2.638161
# 17                  Radial Velocity       5       14.651000   0.800000
# 13                  Radial Velocity       3     1078.000000   2.530000
# 61                  Radial Velocity       1       39.845000   1.040000
# ...

# %%
Data["method"].str.len()
# Out:
# 0       15
# 1       15
# 2       15
# 3       15
# 4       15
# 5       15
# 6       15
# 7       15
# 8       15
# 9       15
# 10      15
# 11      15
# 12      15
# 13      15
# 14      15
# 15      15
# 16      15
# 17      15
# 18      15
# 19      15
# 20      15
# 21      15
# 22      15
# 23      15
# 24      15
# 25      15
# 26      15
# 27      15
# 28      15
# 29       7
# 30       7
# 31       7
# 32      25
# 33       7
# 34       7
# 35       7
# 36       7
# 37      25
# 38      25
# 39      25
# 40      25
# 41      25
# 42      25
# 43      25
# 44      25
# 45      15
# 46      15
# 47       7
# 48      15
# 49      15
# 50      15
# 51      15
# 52      15
# 53      15
# 54       7
# 55      15
# 56      15
# 57      15
# 58      15
# 59      15
# 60      15
# 61      15
# 62      15
# 63      15
# 64      15
# 65      15
# 66      15
# 67      15
# 68       7
# 69       7
# 70       7
# 71       7
# 72       7
# 73       7
# 74       7
# 75       7
# ...

# %%
Data["method"].str.upper()
# Out:
# 0                     RADIAL VELOCITY
# 1                     RADIAL VELOCITY
# 2                     RADIAL VELOCITY
# 3                     RADIAL VELOCITY
# 4                     RADIAL VELOCITY
# 5                     RADIAL VELOCITY
# 6                     RADIAL VELOCITY
# 7                     RADIAL VELOCITY
# 8                     RADIAL VELOCITY
# 9                     RADIAL VELOCITY
# 10                    RADIAL VELOCITY
# 11                    RADIAL VELOCITY
# 12                    RADIAL VELOCITY
# 13                    RADIAL VELOCITY
# 14                    RADIAL VELOCITY
# 15                    RADIAL VELOCITY
# 16                    RADIAL VELOCITY
# 17                    RADIAL VELOCITY
# 18                    RADIAL VELOCITY
# 19                    RADIAL VELOCITY
# 20                    RADIAL VELOCITY
# 21                    RADIAL VELOCITY
# 22                    RADIAL VELOCITY
# 23                    RADIAL VELOCITY
# 24                    RADIAL VELOCITY
# ...

# %%
Data["method"].str.lower()
# Out:
# 0                     radial velocity
# 1                     radial velocity
# 2                     radial velocity
# 3                     radial velocity
# 4                     radial velocity
# 5                     radial velocity
# 6                     radial velocity
# 7                     radial velocity
# 8                     radial velocity
# 9                     radial velocity
# 10                    radial velocity
# 11                    radial velocity
# 12                    radial velocity
# 13                    radial velocity
# 14                    radial velocity
# 15                    radial velocity
# 16                    radial velocity
# 17                    radial velocity
# 18                    radial velocity
# 19                    radial velocity
# 20                    radial velocity
# 21                    radial velocity
# 22                    radial velocity
# 23                    radial velocity
# 24                    radial velocity
# ...

# %%
Data["method"].str.count("a")
# Out:
# 0       2
# 1       2
# 2       2
# 3       2
# 4       2
# 5       2
# 6       2
# 7       2
# 8       2
# 9       2
# 10      2
# 11      2
# 12      2
# 13      2
# 14      2
# 15      2
# 16      2
# 17      2
# 18      2
# 19      2
# 20      2
# 21      2
# 22      2
# 23      2
# 24      2
# 25      2
# 26      2
# 27      2
# 28      2
# 29      1
# 30      1
# 31      1
# 32      2
# 33      1
# 34      1
# 35      1
# 36      1
# 37      2
# 38      2
# 39      2
# 40      2
# 41      2
# 42      2
# 43      2
# 44      2
# 45      2
# 46      2
# 47      1
# 48      2
# 49      2
# 50      2
# 51      2
# 52      2
# 53      2
# 54      1
# 55      2
# 56      2
# 57      2
# 58      2
# 59      2
# 60      2
# 61      2
# 62      2
# 63      2
# 64      2
# 65      2
# 66      2
# 67      2
# 68      1
# 69      1
# 70      1
# 71      1
# 72      1
# 73      1
# 74      1
# 75      1
# 76      2
# 77      2
# 78      2
# 79      2
# 80      2
# 81      2
# 82      2
# ...

# %%
Data["method"].str.startswith("R").sum()
# Out:
# 553

# %%
Data
# Out:
#                              method  number  orbital_period       mass  \
# 0                   Radial Velocity       1      269.300000   7.100000
# 1                   Radial Velocity       1      874.774000   2.210000
# 2                   Radial Velocity       1      763.000000   2.600000
# 3                   Radial Velocity       1      326.030000  19.400000
# 4                   Radial Velocity       1      516.220000  10.500000
# 5                   Radial Velocity       1      185.840000   4.800000
# 6                   Radial Velocity       1     1773.400000   4.640000
# 7                   Radial Velocity       1      798.500000   2.638161
# 8                   Radial Velocity       1      993.300000  10.300000
# 9                   Radial Velocity       2      452.800000   1.990000
# 10                  Radial Velocity       2      883.000000   0.860000
# 11                  Radial Velocity       1      335.100000   9.880000
# ...

# %%
Data.to_csv("Data.csv")
